# %% [markdown]
# ![Screenshot 2024-03-11 090825.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2024-03-11_091026310.png](data:image/png;base64,...)

# %% [markdown]
# 2)The Numbers

# %% [markdown]
# ![the_numbers (1).png](data:image/png;base64,...)

# %% [markdown]
# ![image_2024-03-11_092609868.png](data:image/png;base64,...)

# %% [markdown]
# 3)Pixelated: Using this web page https://decrypt.imageonline.co/index.php we stack both images in order to get the code
